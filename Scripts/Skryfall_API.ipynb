# %%
import requests
from tkinter import *
from PIL import Image, ImageTk
import urllib
import io

# %%
name = str(input("Carta: "))
# Out:
# Carta: Sun titan

# %%
url = "https://api.scryfall.com/cards/named?fuzzy=" + name.replace(" ","+")
imagen_local = r"C:\Users\dfernandez\Downloads\nph-104-birthing-pod.png"

# %%
r = requests.get(url)

# %%
r.json()
# Out:
# {'object': 'card',
#  'id': 'dfbf6204-f08e-4bdc-904d-d617dabdfdd8',
#  'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#  'multiverse_ids': [519141],
#  'mtgo_id': 89313,
#  'tcgplayer_id': 236079,
#  'cardmarket_id': 558508,
#  'name': 'Sun Titan',
#  'lang': 'en',
#  'released_at': '2021-04-23',
#  'uri': 'https://api.scryfall.com/cards/dfbf6204-f08e-4bdc-904d-d617dabdfdd8',
#  'scryfall_uri': 'https://scryfall.com/card/c21/106/sun-titan?utm_source=api',
#  'layout': 'normal',
#  'highres_image': True,
#  'image_status': 'highres_scan',
#  'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#   'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#   'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#   'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.png?1617735345',
#   'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#   'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345'},
#  'mana_cost': '{4}{W}{W}',
#  'cmc': 6.0,
#  'type_line': 'Creature — Giant',
#  'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#  'power': '6',
#  'toughness': '6',
#  'colors': ['W'],
#  'color_identity': ['W'],
#  'keywords': ['Vigilance'],
#  'legalities': {'standard': 'not_legal',
#   'future': 'not_legal',
#   'historic': 'not_legal',
#   'gladiator': 'not_legal',
#   'pioneer': 'not_legal',
#   'modern': 'legal',
#   'legacy': 'legal',
#   'pauper': 'not_legal',
#   'vintage': 'legal',
#   'penny': 'not_legal',
#   'commander': 'legal',
#   'brawl': 'not_legal',
#   'duel': 'legal',
#   'oldschool': 'not_legal',
#   'premodern': 'not_legal'},
#  'games': ['paper', 'mtgo'],
#  'reserved': False,
#  'foil': False,
#  'nonfoil': True,
#  'oversized': False,
#  'promo': False,
#  'reprint': True,
#  'variation': False,
#  'set': 'c21',
#  'set_name': 'Commander 2021',
#  'set_type': 'commander',
#  'set_uri': 'https://api.scryfall.com/sets/27bf6dbd-a9e1-4904-afa7-d28fc7745c4f',
#  'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac21&unique=prints',
#  'scryfall_set_uri': 'https://scryfall.com/sets/c21?utm_source=api',
#  'rulings_uri': 'https://api.scryfall.com/cards/dfbf6204-f08e-4bdc-904d-d617dabdfdd8/rulings',
#  'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#  'collector_number': '106',
#  'digital': False,
#  'rarity': 'mythic',
#  'flavor_text': 'A blazing sun that never sets.',
#  'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#  'artist': 'Todd Lockwood',
#  'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#  'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#  'border_color': 'black',
#  'frame': '2015',
#  'full_art': False,
#  'textless': False,
#  'booster': False,
#  'story_spotlight': False,
#  'edhrec_rank': 96,
#  'prices': {'usd': '0.57',
#   'usd_foil': None,
#   'eur': '0.35',
#   'eur_foil': None,
#   'tix': None},
#  'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=519141',
#   'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#   'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#   'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#   'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#  'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=236079&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#   'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#   'cardhoarder': 'https://www.cardhoarder.com/cards/89313?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}

# %% [markdown]
# # Imagen

# %%
x = r.json().get('image_uris').get('small')

# %%
print(x)
# Out:
# https://c1.scryfall.com/file/scryfall-cards/small/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345

# %%
imagen = urllib.request.urlopen(str(x)).read()
im = Image.open(io.BytesIO(imagen))

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=146x204 at 0x248F4F51310>

# %% [markdown]
# # Bulk Data

# %%
bulk_data = requests.get("https://api.scryfall.com/bulk-data")

# %%
bulk_data.json()
# Out:
# {'object': 'list',
#  'has_more': False,
#  'data': [{'object': 'bulk_data',
#    'id': '27bf3214-1271-490b-bdfe-c0be6c23d02e',
#    'type': 'oracle_cards',
#    'updated_at': '2021-06-23T21:06:04.531+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/27bf3214-1271-490b-bdfe-c0be6c23d02e',
#    'name': 'Oracle Cards',
#    'description': 'A JSON file containing one Scryfall card object for each Oracle ID on Scryfall. The chosen sets for the cards are an attempt to return the most up-to-date recognizable version of the card.',
#    'compressed_size': 12084447,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/oracle-cards/oracle-cards-20210623210604.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '6bbcf976-6369-4401-88fc-3a9e4984c305',
#    'type': 'unique_artwork',
#    'updated_at': '2021-06-23T21:21:18.593+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/6bbcf976-6369-4401-88fc-3a9e4984c305',
#    'name': 'Unique Artwork',
#    'description': 'A JSON file of Scryfall card objects that together contain all unique artworks. The chosen cards promote the best image scans.',
#    'compressed_size': 14848796,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/unique-artwork/unique-artwork-20210623212118.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': 'e2ef41e3-5778-4bc2-af3f-78eca4dd9c23',
#    'type': 'default_cards',
#    'updated_at': '2021-06-23T21:04:02.799+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/e2ef41e3-5778-4bc2-af3f-78eca4dd9c23',
#    'name': 'Default Cards',
#    'description': 'A JSON file containing every card object on Scryfall in English or the printed language if the card is only available in one language.',
#    'compressed_size': 30228000,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/default-cards/default-cards-20210623210402.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '922288cb-4bef-45e1-bb30-0c2bd3d3534f',
#    'type': 'all_cards',
#    'updated_at': '2021-06-23T21:19:33.328+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/922288cb-4bef-45e1-bb30-0c2bd3d3534f',
#    'name': 'All Cards',
#    'description': 'A JSON file containing every card object on Scryfall in every language.',
#    'compressed_size': 194633091,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/all-cards/all-cards-20210623211933.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'},
#   {'object': 'bulk_data',
#    'id': '06f54c0b-ab9c-452d-b35a-8297db5eb940',
#    'type': 'rulings',
#    'updated_at': '2021-06-23T21:06:27.676+00:00',
#    'uri': 'https://api.scryfall.com/bulk-data/06f54c0b-ab9c-452d-b35a-8297db5eb940',
#    'name': 'Rulings',
#    'description': 'A JSON file containing all Rulings on Scryfall. Each ruling refers to cards via an `oracle_id`.',
#    'compressed_size': 2883058,
#    'download_uri': 'https://c2.scryfall.com/file/scryfall-bulk/rulings/rulings-20210623210627.json',
#    'content_type': 'application/json',
#    'content_encoding': 'gzip'}]}

# %% [markdown]
# # Reimpresiones

# %%
reimpresiones_url = r.json()['prints_search_uri']

# %%
reimpresiones_json = requests.get(reimpresiones_url).json()

# %%
reimpresiones_json
# Out:
# {'object': 'list',
#  'total_cards': 15,
#  'has_more': False,
#  'data': [{'object': 'card',
#    'id': '959c5776-450d-4619-80d8-81e65bf0373d',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [],
#    'tcgplayer_id': 240879,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2021-06-19',
#    'uri': 'https://api.scryfall.com/cards/959c5776-450d-4619-80d8-81e65bf0373d',
#    'scryfall_uri': 'https://scryfall.com/card/plist/412/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.jpg?1622846400',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.jpg?1622846400',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.jpg?1622846400',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.png?1622846400',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.jpg?1622846400',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/9/5/959c5776-450d-4619-80d8-81e65bf0373d.jpg?1622846400'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': True,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'plist',
#    'set_name': 'The List',
#    'set_type': 'masters',
#    'set_uri': 'https://api.scryfall.com/sets/67e47ba2-b019-4181-9005-fe9fc021de44',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Aplist&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/plist?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/959c5776-450d-4619-80d8-81e65bf0373d/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '412',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '2.95',
#     'usd_foil': None,
#     'eur': None,
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=240879&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'dfbf6204-f08e-4bdc-904d-d617dabdfdd8',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [519141],
#    'mtgo_id': 89313,
#    'tcgplayer_id': 236079,
#    'cardmarket_id': 558508,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2021-04-23',
#    'uri': 'https://api.scryfall.com/cards/dfbf6204-f08e-4bdc-904d-d617dabdfdd8',
#    'scryfall_uri': 'https://scryfall.com/card/c21/106/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.png?1617735345',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/d/f/dfbf6204-f08e-4bdc-904d-d617dabdfdd8.jpg?1617735345'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper', 'mtgo'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'c21',
#    'set_name': 'Commander 2021',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/27bf6dbd-a9e1-4904-afa7-d28fc7745c4f',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac21&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/c21?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/dfbf6204-f08e-4bdc-904d-d617dabdfdd8/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '106',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.57',
#     'usd_foil': None,
#     'eur': '0.35',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=519141',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=236079&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/89313?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'b7e857aa-955e-4afa-9afe-a572fe27765a',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [508324],
#    'tcgplayer_id': 231280,
#    'cardmarket_id': 535173,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2021-02-05',
#    'uri': 'https://api.scryfall.com/cards/b7e857aa-955e-4afa-9afe-a572fe27765a',
#    'scryfall_uri': 'https://scryfall.com/card/khc/34/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.jpg?1620529429',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.jpg?1620529429',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.jpg?1620529429',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.png?1620529429',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.jpg?1620529429',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/b/7/b7e857aa-955e-4afa-9afe-a572fe27765a.jpg?1620529429'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'khc',
#    'set_name': 'Kaldheim Commander',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/d532ef25-e52b-4276-941a-3a1c095544b0',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Akhc&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/khc?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/b7e857aa-955e-4afa-9afe-a572fe27765a/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '34',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.63',
#     'usd_foil': None,
#     'eur': '0.38',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=508324',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=231280&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'ef3e7352-5768-4d4e-befb-560b9d10a178',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [495959],
#    'tcgplayer_id': 222638,
#    'cardmarket_id': 504255,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2020-09-25',
#    'uri': 'https://api.scryfall.com/cards/ef3e7352-5768-4d4e-befb-560b9d10a178',
#    'scryfall_uri': 'https://scryfall.com/card/znc/21/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.jpg?1604195833',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.jpg?1604195833',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.jpg?1604195833',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.png?1604195833',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.jpg?1604195833',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/e/f/ef3e7352-5768-4d4e-befb-560b9d10a178.jpg?1604195833'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': True,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'znc',
#    'set_name': 'Zendikar Rising Commander',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/25c6bd9b-4e10-40a4-b9b5-0f4d9b5852a1',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Aznc&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/znc?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/ef3e7352-5768-4d4e-befb-560b9d10a178/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '21',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.56',
#     'usd_foil': None,
#     'eur': '0.50',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=495959',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=222638&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'd5529c38-3071-40c8-8afb-12e84f8cb4c8',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [482729],
#    'tcgplayer_id': 212422,
#    'cardmarket_id': 453688,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2020-04-17',
#    'uri': 'https://api.scryfall.com/cards/d5529c38-3071-40c8-8afb-12e84f8cb4c8',
#    'scryfall_uri': 'https://scryfall.com/card/c20/101/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.jpg?1591320159',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.jpg?1591320159',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.jpg?1591320159',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.png?1591320159',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.jpg?1591320159',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/d/5/d5529c38-3071-40c8-8afb-12e84f8cb4c8.jpg?1591320159'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper', 'mtgo'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'c20',
#    'set_name': 'Commander 2020',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/f60ec786-1f8d-42f7-9abc-0d880fe243f6',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac20&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/c20?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/d5529c38-3071-40c8-8afb-12e84f8cb4c8/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '101',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.53',
#     'usd_foil': None,
#     'eur': '0.44',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=482729',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=212422&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': '3ccf318d-5ca5-4e4c-a78a-206a815f9381',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [470622],
#    'mtgo_id': 77266,
#    'tcgplayer_id': 196565,
#    'cardmarket_id': 391942,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2019-08-23',
#    'uri': 'https://api.scryfall.com/cards/3ccf318d-5ca5-4e4c-a78a-206a815f9381',
#    'scryfall_uri': 'https://scryfall.com/card/c19/76/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.jpg?1568003923',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.jpg?1568003923',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.jpg?1568003923',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.png?1568003923',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.jpg?1568003923',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/3/c/3ccf318d-5ca5-4e4c-a78a-206a815f9381.jpg?1568003923'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper', 'mtgo'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'c19',
#    'set_name': 'Commander 2019',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/0fa3ccbb-d86d-4a2e-a55e-c4979c4feeb2',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac19&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/c19?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/3ccf318d-5ca5-4e4c-a78a-206a815f9381/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '76',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.60',
#     'usd_foil': None,
#     'eur': '0.38',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=470622',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=196565&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/77266?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': '8a72ad43-0723-4344-9e5a-43e6313b9876',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [446773],
#    'tcgplayer_id': 166938,
#    'cardmarket_id': 358690,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2018-06-08',
#    'uri': 'https://api.scryfall.com/cards/8a72ad43-0723-4344-9e5a-43e6313b9876',
#    'scryfall_uri': 'https://scryfall.com/card/cm2/37/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.jpg?1562274633',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.jpg?1562274633',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.jpg?1562274633',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.png?1562274633',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.jpg?1562274633',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/8/a/8a72ad43-0723-4344-9e5a-43e6313b9876.jpg?1562274633'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'cm2',
#    'set_name': 'Commander Anthology Volume II',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/2ba5b1a3-40ed-422e-981d-56753004dfc6',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Acm2&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/cm2?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/8a72ad43-0723-4344-9e5a-43e6313b9876/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '37',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.94',
#     'usd_foil': None,
#     'eur': '1.15',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=446773',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=166938&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'cd7a20a2-4489-42c7-9a39-4e2de95c77e2',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [430560],
#    'tcgplayer_id': 132290,
#    'cardmarket_id': 298341,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2017-06-16',
#    'uri': 'https://api.scryfall.com/cards/cd7a20a2-4489-42c7-9a39-4e2de95c77e2',
#    'scryfall_uri': 'https://scryfall.com/card/e01/21/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.jpg?1592765430',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.jpg?1592765430',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.jpg?1592765430',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.png?1592765430',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.jpg?1592765430',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/c/d/cd7a20a2-4489-42c7-9a39-4e2de95c77e2.jpg?1592765430'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'e01',
#    'set_name': 'Archenemy: Nicol Bolas',
#    'set_type': 'archenemy',
#    'set_uri': 'https://api.scryfall.com/sets/bf058cce-027d-4784-85e7-2750533a11df',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ae01&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/e01?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/cd7a20a2-4489-42c7-9a39-4e2de95c77e2/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '21',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.87',
#     'usd_foil': None,
#     'eur': '1.00',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=430560',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=132290&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'd4019088-dbd9-4dc1-b7e3-24a99e5b3d34',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [405400],
#    'tcgplayer_id': 108046,
#    'cardmarket_id': 285836,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2015-11-13',
#    'uri': 'https://api.scryfall.com/cards/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34',
#    'scryfall_uri': 'https://scryfall.com/card/c15/82/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.jpg?1562710089',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.jpg?1562710089',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.jpg?1562710089',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.png?1562710089',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.jpg?1562710089',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/d/4/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34.jpg?1562710089'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'c15',
#    'set_name': 'Commander 2015',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/ea6c99f9-5489-4504-b30c-c819fa3b1fd3',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac15&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/c15?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/d4019088-dbd9-4dc1-b7e3-24a99e5b3d34/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '82',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.84',
#     'usd_foil': None,
#     'eur': '0.80',
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=405400',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=108046&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'be5f45bb-de82-4e64-a9c3-e8bac5d4fa75',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [389699],
#    'mtgo_id': 54865,
#    'mtgo_foil_id': 54866,
#    'tcgplayer_id': 94248,
#    'cardmarket_id': 270545,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2014-11-07',
#    'uri': 'https://api.scryfall.com/cards/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75',
#    'scryfall_uri': 'https://scryfall.com/card/c14/91/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.jpg?1561957068',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.jpg?1561957068',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.jpg?1561957068',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.png?1561957068',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.jpg?1561957068',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/b/e/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75.jpg?1561957068'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper', 'mtgo'],
#    'reserved': False,
#    'foil': False,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': True,
#    'variation': False,
#    'set': 'c14',
#    'set_name': 'Commander 2014',
#    'set_type': 'commander',
#    'set_uri': 'https://api.scryfall.com/sets/0980a6e2-eb78-4ad2-8396-cef08fce365e',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ac14&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/c14?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/be5f45bb-de82-4e64-a9c3-e8bac5d4fa75/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '91',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '0.61',
#     'usd_foil': None,
#     'eur': '0.70',
#     'eur_foil': None,
#     'tix': '0.64'},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=389699',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=94248&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/54865?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'f7bdf6bd-472e-4109-9864-68a2df757775',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [373379],
#    'mtgo_id': 49983,
#    'mtgo_foil_id': 49984,
#    'tcgplayer_id': 70941,
#    'cardmarket_id': 263715,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2013-09-06',
#    'uri': 'https://api.scryfall.com/cards/f7bdf6bd-472e-4109-9864-68a2df757775',
#    'scryfall_uri': 'https://scryfall.com/card/ddl/1/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.jpg?1537149840',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.jpg?1537149840',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.jpg?1537149840',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.png?1537149840',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.jpg?1537149840',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/f/7/f7bdf6bd-472e-4109-9864-68a2df757775.jpg?1537149840'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
# ...
#    'set_type': 'core',
#    'set_uri': 'https://api.scryfall.com/sets/5cdd2643-229c-4441-a62a-c34e4b531e1c',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Am12&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/m12?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/ea3e77ed-9015-4407-b78c-494e46b67b07/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '39',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2003',
#    'full_art': False,
#    'textless': False,
#    'booster': True,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '1.60',
#     'usd_foil': '9.98',
#     'eur': '1.50',
#     'eur_foil': '11.99',
#     'tix': '0.52'},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=241833',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=47685&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/41309?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': '029946b5-3d15-4a72-9d1a-bb36347a87a0',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [],
#    'mtgo_id': 37596,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2010-11-04',
#    'uri': 'https://api.scryfall.com/cards/029946b5-3d15-4a72-9d1a-bb36347a87a0',
#    'scryfall_uri': 'https://scryfall.com/card/prm/37596/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': False,
#    'image_status': 'lowres',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.jpg?1562542588',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.jpg?1562542588',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.jpg?1562542588',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.png?1562542588',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.jpg?1562542588',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/0/2/029946b5-3d15-4a72-9d1a-bb36347a87a0.jpg?1562542588'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['mtgo'],
#    'reserved': False,
#    'foil': True,
#    'nonfoil': False,
#    'oversized': False,
#    'promo': True,
#    'reprint': True,
#    'variation': False,
#    'set': 'prm',
#    'set_name': 'Magic Online Promos',
#    'set_type': 'promo',
#    'set_uri': 'https://api.scryfall.com/sets/638940fb-6be9-4be3-b83f-68d3902fbbe5',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Aprm&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/prm?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/029946b5-3d15-4a72-9d1a-bb36347a87a0/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '37596',
#    'digital': True,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Chris Rahn',
#    'artist_ids': ['7742047e-0f80-4c0f-a530-d07460165e86'],
#    'illustration_id': '754758ef-7ddf-429c-ad00-20e25399c572',
#    'border_color': 'black',
#    'frame': '2003',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': None,
#     'usd_foil': None,
#     'eur': None,
#     'eur_foil': None,
#     'tix': '0.60'},
#    'related_uris': {'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://www.tcgplayer.com/search/magic/product?productLineName=magic&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/37596?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'd8db2b8e-dce9-49b7-833f-381ee55288cb',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [205030],
#    'mtgo_id': 37406,
#    'mtgo_foil_id': 37407,
#    'tcgplayer_id': 35396,
#    'cardmarket_id': 241818,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2010-07-16',
#    'uri': 'https://api.scryfall.com/cards/d8db2b8e-dce9-49b7-833f-381ee55288cb',
#    'scryfall_uri': 'https://scryfall.com/card/m11/35/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.jpg?1562477599',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.jpg?1562477599',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.jpg?1562477599',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.png?1562477599',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.jpg?1562477599',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/d/8/d8db2b8e-dce9-49b7-833f-381ee55288cb.jpg?1562477599'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper', 'mtgo'],
#    'reserved': False,
#    'foil': True,
#    'nonfoil': True,
#    'oversized': False,
#    'promo': False,
#    'reprint': False,
#    'variation': False,
#    'set': 'm11',
#    'set_name': 'Magic 2011',
#    'set_type': 'core',
#    'set_uri': 'https://api.scryfall.com/sets/485d2468-18c8-42a4-9482-ca1c51e0470e',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Am11&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/m11?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/d8db2b8e-dce9-49b7-833f-381ee55288cb/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '35',
#    'digital': False,
#    'rarity': 'mythic',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Todd Lockwood',
#    'artist_ids': ['d0b9f3cc-13fb-42b6-bc43-b034728e5c7b'],
#    'illustration_id': 'dd5a7ad8-2b13-406e-89f7-3c10953d72cf',
#    'border_color': 'black',
#    'frame': '2003',
#    'full_art': False,
#    'textless': False,
#    'booster': True,
#    'story_spotlight': False,
#    'edhrec_rank': 96,
#    'prices': {'usd': '1.66',
#     'usd_foil': '13.93',
#     'eur': '0.99',
#     'eur_foil': '3.99',
#     'tix': '0.50'},
#    'related_uris': {'gatherer': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=205030',
#     'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=35396&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards/37406?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}},
#   {'object': 'card',
#    'id': 'bb07690e-d816-46de-84e7-617149a51b18',
#    'oracle_id': 'b2e950fb-cb7e-40a0-a311-5bbdd0477b29',
#    'multiverse_ids': [],
#    'tcgplayer_id': 38401,
#    'cardmarket_id': 241947,
#    'name': 'Sun Titan',
#    'lang': 'en',
#    'released_at': '2010-07-15',
#    'uri': 'https://api.scryfall.com/cards/bb07690e-d816-46de-84e7-617149a51b18',
#    'scryfall_uri': 'https://scryfall.com/card/pm11/35%E2%98%85/sun-titan?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://c1.scryfall.com/file/scryfall-cards/small/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.jpg?1605361637',
#     'normal': 'https://c1.scryfall.com/file/scryfall-cards/normal/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.jpg?1605361637',
#     'large': 'https://c1.scryfall.com/file/scryfall-cards/large/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.jpg?1605361637',
#     'png': 'https://c1.scryfall.com/file/scryfall-cards/png/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.png?1605361637',
#     'art_crop': 'https://c1.scryfall.com/file/scryfall-cards/art_crop/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.jpg?1605361637',
#     'border_crop': 'https://c1.scryfall.com/file/scryfall-cards/border_crop/front/b/b/bb07690e-d816-46de-84e7-617149a51b18.jpg?1605361637'},
#    'mana_cost': '{4}{W}{W}',
#    'cmc': 6.0,
#    'type_line': 'Creature — Giant',
#    'oracle_text': 'Vigilance\nWhenever Sun Titan enters the battlefield or attacks, you may return target permanent card with mana value 3 or less from your graveyard to the battlefield.',
#    'power': '6',
#    'toughness': '6',
#    'colors': ['W'],
#    'color_identity': ['W'],
#    'keywords': ['Vigilance'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'legal',
#     'legacy': 'legal',
#     'pauper': 'not_legal',
#     'vintage': 'legal',
#     'penny': 'not_legal',
#     'commander': 'legal',
#     'brawl': 'not_legal',
#     'duel': 'legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal'},
#    'games': ['paper'],
#    'reserved': False,
#    'foil': True,
#    'nonfoil': False,
#    'oversized': False,
#    'promo': True,
#    'reprint': True,
#    'variation': False,
#    'set': 'pm11',
#    'set_name': 'Magic 2011 Promos',
#    'set_type': 'promo',
#    'set_uri': 'https://api.scryfall.com/sets/8d3a0693-6b2a-4955-aeda-4888b2665dd0',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Apm11&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/pm11?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/bb07690e-d816-46de-84e7-617149a51b18/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ab2e950fb-cb7e-40a0-a311-5bbdd0477b29&unique=prints',
#    'collector_number': '35★',
#    'digital': False,
#    'rarity': 'mythic',
#    'watermark': 'set',
#    'flavor_text': 'A blazing sun that never sets.',
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Chris Rahn',
#    'artist_ids': ['7742047e-0f80-4c0f-a530-d07460165e86'],
#    'illustration_id': '754758ef-7ddf-429c-ad00-20e25399c572',
#    'border_color': 'black',
#    'frame': '2003',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'promo_types': ['setpromo', 'datestamped', 'prerelease'],
#    'edhrec_rank': 96,
#    'prices': {'usd': None,
#     'usd_foil': '5.61',
#     'eur': None,
#     'eur_foil': '0.99',
#     'tix': None},
#    'related_uris': {'tcgplayer_infinite_articles': 'https://infinite.tcgplayer.com/search?contentMode=article&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'tcgplayer_infinite_decks': 'https://infinite.tcgplayer.com/search?contentMode=deck&game=magic&partner=scryfall&q=Sun+Titan&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'edhrec': 'https://edhrec.com/route/?cc=Sun+Titan',
#     'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Sun+Titan'},
#    'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=38401&utm_campaign=affiliate&utm_medium=api&utm_source=scryfall',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Sun+Titan&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Sun+Titan&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}]}

# %%
len(reimpresiones_json['data'])
# Out:
# 15

# %%
for e in range(len(reimpresiones_json['data'])):
    print(reimpresiones_json['data'][e]['set_name'])
# Out:
# The List
# Commander 2021
# Kaldheim Commander
# Zendikar Rising Commander
# Commander 2020
# Commander 2019
# Commander Anthology Volume II
# Archenemy: Nicol Bolas
# Commander 2015
# Commander 2014
# Duel Decks: Heroes vs. Monsters
# Magic 2012
# Magic Online Promos
# Magic 2011
# Magic 2011 Promos
