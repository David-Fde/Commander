# %%
from numpy.lib.function_base import place
import pandas as pd
import os

PlainText_Decklists = r"..\Datos\PlainText_Decklists"
Datos = r"..\Datos"


# https://tugbucket.net/tests/salvation/mtg_sets/ Pagina para descargar las colecciones en texto plano.

def PlainTextToExcel(respuesta):
    if respuesta == "1":
        os.system("cls")
        lista = os.listdir(PlainText_Decklists)
        contador = 1
        for e in lista:
            print(f"Opción{contador}: {e}")
            contador += 1
        opcion = int(input("Opción: ")) -1
        df = pd.read_excel(f"{Datos}\Decklists.xlsx", header=None)
        f = open(PlainText_Decklists + f"\{lista[opcion]}","r+")
        text = f.read()
        text = text.splitlines()
        for e in range(len(text)):
            text[e] = text[e].rstrip()
        for e in range(len(text)):
            if text[e][0] != "1":
                contador = 0
                while contador < int(text[e][0]):
                    text.append(f"1 {text[e][2:]}")
                    contador += 1
            text.remove(text[e])
        df[f"lista[{opcion}].split('.')[0]"] = text
        df.to_excel(f"{Datos}\Decklists.xlsx", index=False)
        input("Press enter to close")
    return

# %%
PlainTextToExcel(1)

# %%
os.system("cls")
lista = os.listdir(PlainText_Decklists)
contador = 1
for e in lista:
    print(f"Opción{contador}: {e}")
    contador += 1
opcion = int(input("Opción: ")) -1
df = pd.read_excel(f"{Datos}\Decklists.xlsx", header=None)
f = open(PlainText_Decklists + f"\{lista[opcion]}","r+")
text = f.read()
text = text.splitlines()
for e in range(len(text)):
    text[e] = text[e].rstrip()
# Out:
# Opción1: Emry, Lurker of the Loch.txt
# Opción2: Leovold, Emissary of Trest.txt
# Opción3: Narset, Enlightened Master.txt
# Opción4: Winota, Joiner of Forces.txt
# Opción: 1
# 1 Walking Ballista
# 1 Myr Retriever
# 1 Spellskite
# 1 Laboratory Maniac
# 1 Sai, Master Thopterist
# 1 Spellseeker
# 1 Trophy Mage
# 1 Pact of Negation
# 1 Dispel
# 1 Mental Misstep
# 1 Ponder
# 1 Preordain
# 1 Serum Visions
# 1 Swan Song
# 1 Counterspell
# 1 Daze
# 1 Logic Knot
# 1 Merchant Scroll
# 1 Negate
# 1 Fierce Guardianship
# 1 Wizard's Retort
# 1 Sea Gate Restoration
# 1 Treasure Cruise
# 1 Everflowing Chalice
# 1 Lotus Petal
# 1 Mishra's Bauble
# 1 Mox Diamond
# 1 Tormod's Crypt
# 1 Welding Jar
# 1 Chromatic Sphere
# 1 Conjurer's Bauble
# 1 Mana Vault
# 1 Sol Ring
# 1 Arcane Signet
# 1 Mind Stone
# 1 Krark-Clan Ironworks
# 1 Academy Ruins
# 1 Blast Zone
# 1 Cephalid Coliseum
# 1 Flooded Strand
# 5 Island
# 1 Misty Rainforest
# 1 Polluted Delta
# 1 Riptide Laboratory
# 1 Seat of the Synod
# 1 Tectonic Edge
# 1 Island
# 1 Island
# 1 Island
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-41d5f408d9af> in <module>
#      11 text = text.splitlines()
#      12 for e in range(len(text)):
# ---> 13     print(text[e])
#      14     text[e] = text[e].rstrip()
#      15     if text[e][0] != "1":
#
# IndexError: list index out of range

# %%
for e in range(len(text)):
    print(text[e])
# Out:
# 1 Aether Chaser
# 1 Snapcaster Mage
# 1 Emry, Lurker of the Loch
# 1 Mirran Spy
# 1 Scrap Trawler
# 1 Trinket Mage
# 1 Urza, Lord High Artificer
# 1 Brainstorm
# 1 Force Spike
# 1 Mystical Tutor
# 1 Pongify
# 1 Rapid Hybridization
# 1 Spell Pierce
# 1 Arcane Denial
# 1 Cyclonic Rift
# 1 Delay
# 1 Memory Lapse
# 1 Muddle the Mixture
# 1 Fabricate
# 1 Whir of Invention
# 1 Force of Will
# 1 Dig Through Time
# 1 Chrome Mox
# 1 Lodestone Bauble
# 1 Mana Crypt
# 1 Mox Amber
# 1 Mox Opal
# 1 Urza's Bauble
# 1 Aether Spellbomb
# 1 Chromatic Star
# 1 Expedition Map
# 1 Manifold Key
# 1 Voltaic Key
# 1 Grim Monolith
# 1 Commander's Sphere
# 1 Paradox Engine
# 1 Ancient Tomb
# 1 Cavern of Souls
# 1 Darksteel Citadel
# 1 Inventors' Fair
# 1 Minamo, School at Water's Edge
# 1 Mystic Sanctuary
# 1 Prismatic Vista
# 1 Scalding Tarn
# 5 Snow-Covered Island
# 1 Wasteland
# 1 Island
# 1 Island
